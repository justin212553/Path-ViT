# %%
# !git clone https://github.com/justin212553/Path-ViT
# Out:
# Cloning into 'Path-ViT'...
# remote: Enumerating objects: 1321, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 1321 (delta 46), reused 84 (delta 34), pack-reused 1216 (from 2)
# Receiving objects: 100% (1321/1321), 109.99 MiB | 25.41 MiB/s, done.
# Resolving deltas: 100% (850/850), done.
# Updating files: 100% (174/174), done.

# %%
# %cd /kaggle/working
# !pip install -r ./Path-ViT/requirements.txt
# Out:
# /kaggle/working
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.1/409.1 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 7.3 MB/s eta 0:00:00
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4118 sha256=4497d83e6abc1db5d9cfe08214de6d88881f639b1e9e4e8fd0fda6609de2d90d
#   Stored in directory: /root/.cache/pip/wheels/50/37/21/0a719b9d89c635e89ff24bd93b862882ad675279552013b2fb
# Successfully built autograd-gamma
# ...

# %%
from kaggle_secrets import UserSecretsClient
import wandb
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("WANDB_API_KEY")

wandb.login(key=secret_value_0)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: justin212553 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# %cd /kaggle/working/Path-ViT
# !mkdir -p ./data/tile_cache_512
# !mkdir -p ./data/patches_tcga
# !mkdir -p ./data/patches_cptac
# !ln -s /kaggle/input/datasets/wonseukleejustinlee/path-vit-tile512b/tile_cache_512 data/tile_cache_512
# !ln -s /kaggle/input/datasets/wonseukleejustinlee/path-vit-patches-tcga-b /kaggle/working/Path-ViT/data/patches_tcga
# !ln -s /kaggle/input/datasets/wonseukleejustinlee/path-vit-patches-cptac /kaggle/working/Path-ViT/data/patches_cptac
# Out:
# /kaggle/working/Path-ViT

# %%
# %cd /kaggle/working/Path-ViT
# !python train_multi.py --M1 --M2 --M3 --PMA --dataset tcga --external --tile-augment --seed 42 --tile-cache-maxsize 30000
# Out:
# /kaggle/working/Path-ViT
# Traceback (most recent call last):
#   File "/kaggle/working/Path-ViT/train_multi.py", line 347, in <module>
#     main()
#   File "/kaggle/working/Path-ViT/train_multi.py", line 212, in main
#     train_ds = _make_ds("train", train_transform)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/Path-ViT/train_multi.py", line 207, in _make_ds
#     return WSISurvivalDataset(cfg.data, dataset=args.dataset, split=split, transform=transform, **ds_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/Path-ViT/data/dataset.py", line 406, in __init__
#     slide_df = _load_slide_index(root)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/Path-ViT/data/dataset.py", line 166, in _load_slide_index
#     raise FileNotFoundError(
# ...
